#   inflating: /content/dataset/train/surprise/Training_99279802.jpg
#   inflating: /content/dataset/train/surprise/Training_99318660.jpg
#   inflating: /content/dataset/train/surprise/Training_9932811.jpg
#   inflating: /content/dataset/train/surprise/Training_99399304.jpg
#   inflating: /content/dataset/train/surprise/Training_99399823.jpg
#   inflating: /content/dataset/train/surprise/Training_99404349.jpg
#   inflating: /content/dataset/train/surprise/Training_9943398.jpg
#   inflating: /content/dataset/train/surprise/Training_99441101.jpg
#   inflating: /content/dataset/train/surprise/Training_99576616.jpg
#   inflating: /content/dataset/train/surprise/Training_99604118.jpg
#   inflating: /content/dataset/train/surprise/Training_99663019.jpg
#   inflating: /content/dataset/train/surprise/Training_99791966.jpg
#   inflating: /content/dataset/train/surprise/Training_99794165.jpg
#   inflating: /content/dataset/train/surprise/Training_99807705.jpg
#   inflating: /content/dataset/train/surprise/Training_99827442.jpg
#   inflating: /content/dataset/train/surprise/Training_99916297.jpg
#   inflating: /content/dataset/train/surprise/Training_99924420.jpg
#   inflating: /content/dataset/train/surprise/Training_99937001.jpg
#   inflating: /content/dataset/train/surprise/Training_99951755.jpg
#   inflating: /content/dataset/train/surprise/Training_99984132.jpg

# %%
import os

# Define the path to the dataset directory
dataset_path = '/content/dataset'

# Initialize a counter
total_images = 0

# Loop over all directories and files in the dataset directory
for dirpath, dirnames, filenames in os.walk(dataset_path):
    # Count only files that are likely to be images
    total_images += sum([1 for f in filenames if f.endswith(('.png', '.jpg', '.jpeg'))])

print(f"Total number of images in the dataset: {total_images}")
# Out:
# Total number of images in the dataset: 35887

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set the path to the dataset
train_path = '/content/dataset/train'
test_path = '/content/dataset/test'

# %%
# Define the label dictionary outside the function for global access
categories = sorted(os.listdir(train_path))  # Ensure it's sorted for consistency
label_dict = {name: i for i, name in enumerate(categories)}

# %%
def load_data(data_path, label_dict):
    images = []
    labels = []
    for category in categories:
        class_folder = os.path.join(data_path, category)
        for img in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img)
            if os.path.isfile(img_path) and img_path.lower().endswith(('.png', '.jpg', '.jpeg')):
                image = plt.imread(img_path)
                if image.ndim == 2:
                    image = np.stack((image,)*3, axis=-1)
                elif image.shape[2] == 4:
                    image = image[..., :3]
                images.append(image)
                labels.append(label_dict[category])
    images = np.array(images, dtype=np.float32) / 255.0  # Normalize images
    labels = np.array(labels, dtype=int)  # Ensure labels are integers
    return images, labels

# %%
# Load train and test data
train_images, train_labels = load_data(train_path, label_dict)
test_images, test_labels = load_data(test_path, label_dict)

# Check the unique classes found and print information
num_classes = len(categories)
print("Total training images:", train_images.shape[0])
print("Total testing images:", test_images.shape[0])
print("Image shape:", train_images[0].shape)
print("Number of classes:", num_classes)
print("Classes:", categories)

# Visualizing the dataset
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(train_images[i].squeeze(), cmap='gray')  #cmap='gray' for grayscale images
    plt.title(list(label_dict.keys())[train_labels[i]])
    plt.axis('off')
plt.show()
# Out:
# Total training images: 28709
# Total testing images: 7178
# Image shape: (48, 48, 3)
# Number of classes: 7
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Convert labels to categorical (one-hot encoding)
train_labels = to_categorical(train_labels, num_classes=7)
test_labels = to_categorical(test_labels, num_classes=7)

# Splitting the dataset for validation
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
# ImageDataGenerator for augmentation
train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.3,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
train_generator = train_datagen.flow(X_train, y_train, batch_size=32)

# %%
import os
from PIL import Image

def dataset_details(train_path):
    categories = os.listdir(train_path)
    num_classes = len(categories)
    image_sizes = []

    # Sample one image per category to determine size
    for category in categories:
        images = os.listdir(os.path.join(train_path, category))
        if images:
            img_path = os.path.join(train_path, category, images[0])
            with Image.open(img_path) as img:
                image_sizes.append(img.size)  # size returns (width, height)

    return num_classes, set(image_sizes)

train_path = '/content/dataset/train'
num_classes, image_sizes = dataset_details(train_path)
print("Number of classes:", num_classes)
print("Image sizes found in dataset:", image_sizes)
# Out:
# Number of classes: 7
# Image sizes found in dataset: {(48, 48)}

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

def build_vgg13_model(input_shape, num_classes):
    model = Sequential([
        # First block
        Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Second block
        Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Third block
        Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        MaxPooling2D((2, 2), strides=(2, 2)),

        # Fully connected layers
        Flatten(),
        Dense(1024, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.5),
        Dense(1024, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    return model

# Assuming input_shape is already set, for example:
input_shape = (48, 48, 3)  # Must match your dataset image size
num_classes = 7  # Adjusted to your dataset

# Build and compile the VGG-13 model
vgg13_model = build_vgg13_model(input_shape, num_classes)
vgg13_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary to confirm the configuration
vgg13_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        1792
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_1 (Bat  (None, 48, 48, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_4 (Bat  (None, 12, 12, 256)       1024
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_5 (Bat  (None, 12, 12, 256)       1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 11643975 (44.42 MB)
# Trainable params: 11642183 (44.41 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Setup model checkpoint to only save the best model
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# %%
import tensorflow as tf
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

lr_scheduler = LearningRateScheduler(scheduler, verbose=1)

# Train the model
history = vgg13_model.fit(
    train_generator,
    epochs=20,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, lr_scheduler, early_stopping]
)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/20
# 718/718 [==============================] - ETA: 0s - loss: 28.6380 - accuracy: 0.2192
# Epoch 1: val_accuracy improved from -inf to 0.26437, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 718/718 [==============================] - 42s 45ms/step - loss: 28.6380 - accuracy: 0.2192 - val_loss: 20.0570 - val_accuracy: 0.2644 - lr: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/20
# 717/718 [============================>.] - ETA: 0s - loss: 14.6983 - accuracy: 0.2347
# Epoch 2: val_accuracy improved from 0.26437 to 0.27308, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 14.6922 - accuracy: 0.2349 - val_loss: 10.3882 - val_accuracy: 0.2731 - lr: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/20
# 718/718 [==============================] - ETA: 0s - loss: 7.9184 - accuracy: 0.2413
# Epoch 3: val_accuracy improved from 0.27308 to 0.29345, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 7.9184 - accuracy: 0.2413 - val_loss: 5.8783 - val_accuracy: 0.2935 - lr: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/20
# 718/718 [==============================] - ETA: 0s - loss: 4.7553 - accuracy: 0.2667
# Epoch 4: val_accuracy improved from 0.29345 to 0.30442, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 4.7553 - accuracy: 0.2667 - val_loss: 3.7649 - val_accuracy: 0.3044 - lr: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/20
# 717/718 [============================>.] - ETA: 0s - loss: 3.2453 - accuracy: 0.3046
# Epoch 5: val_accuracy improved from 0.30442 to 0.36451, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 3.2447 - accuracy: 0.3047 - val_loss: 2.7704 - val_accuracy: 0.3645 - lr: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.048373613040894e-05.
# Epoch 6/20
# 718/718 [==============================] - ETA: 0s - loss: 2.5267 - accuracy: 0.3770
# Epoch 6: val_accuracy improved from 0.36451 to 0.44619, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 2.5267 - accuracy: 0.3770 - val_loss: 2.2276 - val_accuracy: 0.4462 - lr: 9.0484e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 8.187306229956448e-05.
# Epoch 7/20
# 718/718 [==============================] - ETA: 0s - loss: 2.1984 - accuracy: 0.4240
# Epoch 7: val_accuracy improved from 0.44619 to 0.46952, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 2.1984 - accuracy: 0.4240 - val_loss: 2.0660 - val_accuracy: 0.4695 - lr: 8.1873e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 7.408180681522936e-05.
# Epoch 8/20
# 717/718 [============================>.] - ETA: 0s - loss: 2.0008 - accuracy: 0.4668
# Epoch 8: val_accuracy improved from 0.46952 to 0.49948, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 2.0003 - accuracy: 0.4669 - val_loss: 1.8754 - val_accuracy: 0.4995 - lr: 7.4082e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 6.703198596369475e-05.
# Epoch 9/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.8891 - accuracy: 0.4858
# Epoch 9: val_accuracy improved from 0.49948 to 0.53535, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 1.8893 - accuracy: 0.4857 - val_loss: 1.7228 - val_accuracy: 0.5354 - lr: 6.7032e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 6.065304478397593e-05.
# Epoch 10/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.7948 - accuracy: 0.5094
# Epoch 10: val_accuracy improved from 0.53535 to 0.56844, saving model to best_model.h5
# 718/718 [==============================] - 30s 42ms/step - loss: 1.7945 - accuracy: 0.5094 - val_loss: 1.6255 - val_accuracy: 0.5684 - lr: 6.0653e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 5.488114038598724e-05.
# Epoch 11/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.7262 - accuracy: 0.5223
# Epoch 11: val_accuracy did not improve from 0.56844
# 718/718 [==============================] - 29s 41ms/step - loss: 1.7257 - accuracy: 0.5226 - val_loss: 1.7187 - val_accuracy: 0.5265 - lr: 5.4881e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.9658505304250866e-05.
# Epoch 12/20
# 718/718 [==============================] - ETA: 0s - loss: 1.6778 - accuracy: 0.5345
# Epoch 12: val_accuracy improved from 0.56844 to 0.57558, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 1.6778 - accuracy: 0.5345 - val_loss: 1.5594 - val_accuracy: 0.5756 - lr: 4.9659e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.493287269724533e-05.
# Epoch 13/20
# 718/718 [==============================] - ETA: 0s - loss: 1.6244 - accuracy: 0.5480
# Epoch 13: val_accuracy improved from 0.57558 to 0.58603, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 1.6244 - accuracy: 0.5480 - val_loss: 1.5058 - val_accuracy: 0.5860 - lr: 4.4933e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.065694156452082e-05.
# Epoch 14/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5790 - accuracy: 0.5563
# Epoch 14: val_accuracy did not improve from 0.58603
# 718/718 [==============================] - 29s 41ms/step - loss: 1.5792 - accuracy: 0.5563 - val_loss: 1.5180 - val_accuracy: 0.5763 - lr: 4.0657e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.678791836136952e-05.
# Epoch 15/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5416 - accuracy: 0.5649
# Epoch 15: val_accuracy improved from 0.58603 to 0.59648, saving model to best_model.h5
# 718/718 [==============================] - 29s 41ms/step - loss: 1.5415 - accuracy: 0.5649 - val_loss: 1.4595 - val_accuracy: 0.5965 - lr: 3.6788e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 3.328708407934755e-05.
# Epoch 16/20
# 718/718 [==============================] - ETA: 0s - loss: 1.5140 - accuracy: 0.5733
# Epoch 16: val_accuracy did not improve from 0.59648
# 718/718 [==============================] - 29s 41ms/step - loss: 1.5140 - accuracy: 0.5733 - val_loss: 1.4668 - val_accuracy: 0.5829 - lr: 3.3287e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 3.0119397706585005e-05.
# Epoch 17/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.4825 - accuracy: 0.5792
# Epoch 17: val_accuracy did not improve from 0.59648
# 718/718 [==============================] - 29s 40ms/step - loss: 1.4826 - accuracy: 0.5793 - val_loss: 1.4360 - val_accuracy: 0.5944 - lr: 3.0119e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 2.7253156076767482e-05.
# Epoch 18/20
# 718/718 [==============================] - ETA: 0s - loss: 1.4523 - accuracy: 0.5843
# Epoch 18: val_accuracy improved from 0.59648 to 0.61146, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 1.4523 - accuracy: 0.5843 - val_loss: 1.3864 - val_accuracy: 0.6115 - lr: 2.7253e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 2.4659673727001064e-05.
# Epoch 19/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.4241 - accuracy: 0.5920
# Epoch 19: val_accuracy improved from 0.61146 to 0.62226, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 1.4240 - accuracy: 0.5918 - val_loss: 1.3541 - val_accuracy: 0.6223 - lr: 2.4660e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 2.231299367849715e-05.
# Epoch 20/20
# 718/718 [==============================] - ETA: 0s - loss: 1.4093 - accuracy: 0.5956
# Epoch 20: val_accuracy improved from 0.62226 to 0.62940, saving model to best_model.h5
# 718/718 [==============================] - 30s 41ms/step - loss: 1.4093 - accuracy: 0.5956 - val_loss: 1.3372 - val_accuracy: 0.6294 - lr: 2.2313e-05

# %%
from tensorflow.keras.models import load_model

# Load the best saved model
best_model = load_model('best_model.h5')

# Evaluate on the test set
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 180/180 [==============================] - 2s 7ms/step - loss: 1.3372 - accuracy: 0.6294
# Test Accuracy: 62.94%
# Test Loss: 1.3372

# %%
import matplotlib.pyplot as plt

# Plotting training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print("Shape of train_labels after loading and before encoding:", train_labels.shape)
train_labels = to_categorical(train_labels, num_classes=num_classes)
print("Shape of train_labels after one-hot encoding:", train_labels.shape)
# Out:
# Shape of train_labels after loading and before encoding: (28709, 7)
# Shape of train_labels after one-hot encoding: (28709, 7, 7)

# %%
# # ResNet Model Implementation
# from tensorflow.keras.layers import Input, Add, Conv2D, MaxPooling2D, Activation, Flatten, Dense, BatchNormalization
# from tensorflow.keras.models import Model

# def resnet_block(input_tensor, filters, kernel_size=3, strides=1):
#     """
#     A ResNet block consisting of two convolutional layers followed by a skip connection.
#     """
#     x = Conv2D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)

#     x = Conv2D(filters, kernel_size, strides=1, padding='same')(x)
#     x = BatchNormalization()(x)

#     # Skip connection
#     if strides != 1 or input_tensor.shape[-1] != filters:
#         shortcut = Conv2D(filters, (1, 1), strides=strides, padding='same')(input_tensor)
#         shortcut = BatchNormalization()(shortcut)
#     else:
#         shortcut = input_tensor

#     x = Add()([x, shortcut])
#     x = Activation('relu')(x)

#     return x

# def build_resnet_model(input_shape, num_classes):
#     """
#     Builds a simple ResNet model with multiple blocks.
#     """
#     input_tensor = Input(shape=input_shape)

#     # First block (no skip connection needed)
#     x = Conv2D(64, (7, 7), strides=2, padding='same')(input_tensor)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = MaxPooling2D((3, 3), strides=2, padding='same')(x)

#     # Second block
#     x = resnet_block(x, 64)

#     # Third block
#     x = resnet_block(x, 128, strides=2)

#     # Fourth block
#     x = resnet_block(x, 256, strides=2)

#     # Fifth block
#     x = resnet_block(x, 512, strides=2)

#     # Classification layers
#     x = Flatten()(x)
#     x = Dense(1024, activation='relu')(x)
#     x = Dropout(0.5)(x)
#     output_tensor = Dense(num_classes, activation='softmax')(x)

#     model = Model(inputs=input_tensor, outputs=output_tensor)

#     return model


# # Build and compile the ResNet model
# resnet_model = build_resnet_model(input_shape, num_classes)
# resnet_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# # Display the model summary to confirm the configuration
# resnet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]          0         []
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 64)           9472      ['input_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 24, 24, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 24, 24, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 64)           0         ['activation[0][0]']
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 64)           36928     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 12, 12, 64)           256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 12, 12, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 64)           36928     ['activation_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 12, 12, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 12, 12, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     , 'max_pooling2d_3[0][0]']
#
#  activation_2 (Activation)   (None, 12, 12, 64)           0         ['add[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 128)            73856     ['activation_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 6, 6, 128)            512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 128)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 128)            147584    ['activation_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 128)            8320      ['activation_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, 6, 6, 128)            512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 6, 6, 128)            512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_1 (Add)                 (None, 6, 6, 128)            0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_4 (Activation)   (None, 6, 6, 128)            0         ['add_1[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 3, 3, 256)            295168    ['activation_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 3, 3, 256)            1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 3, 3, 256)            0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 256)            590080    ['activation_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 3, 3, 256)            33024     ['activation_4[0][0]']
#
#  batch_normalization_13 (Ba  (None, 3, 3, 256)            1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 3, 3, 256)            1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 3, 3, 256)            0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_6 (Activation)   (None, 3, 3, 256)            0         ['add_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 512)            1180160   ['activation_6[0][0]']
#
#  batch_normalization_15 (Ba  (None, 2, 2, 512)            2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 2, 2, 512)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_7[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 512)            131584    ['activation_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 2, 2, 512)            2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 2, 2, 512)            2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 2, 2, 512)            0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 2, 2, 512)            0         ['add_3[0][0]']
#
#  flatten_1 (Flatten)         (None, 2048)                 0         ['activation_8[0][0]']
#
#  dense_3 (Dense)             (None, 1024)                 2098176   ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 7)                    7175      ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 7019783 (26.78 MB)
# Trainable params: 7014023 (26.76 MB)
# Non-trainable params: 5760 (22.50 KB)
# __________________________________________________________________________________________________

# %%
# import tensorflow as tf
# def scheduler(epoch, lr):
#     if epoch < 5:
#         return lr
#     else:
#         return lr * tf.math.exp(-0.1)

# lr_scheduler = LearningRateScheduler(scheduler, verbose=1)

# # Train the model
# history = resnet_model.fit(
#     train_generator,
#     epochs=20,
#     validation_data=(X_val, y_val),
#     callbacks=[checkpoint, lr_scheduler, early_stopping]
# )
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 1/20
# 718/718 [==============================] - ETA: 0s - loss: 1.8874 - accuracy: 0.2326
# Epoch 1: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 41s 43ms/step - loss: 1.8874 - accuracy: 0.2326 - val_loss: 1.7745 - val_accuracy: 0.2602 - lr: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 2/20
# 718/718 [==============================] - ETA: 0s - loss: 1.7891 - accuracy: 0.2585
# Epoch 2: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.7891 - accuracy: 0.2585 - val_loss: 1.7424 - val_accuracy: 0.2886 - lr: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 3/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.7742 - accuracy: 0.2629
# Epoch 3: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.7743 - accuracy: 0.2629 - val_loss: 1.7661 - val_accuracy: 0.2675 - lr: 1.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 4/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.7600 - accuracy: 0.2746
# Epoch 4: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.7599 - accuracy: 0.2748 - val_loss: 1.6978 - val_accuracy: 0.3299 - lr: 1.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# Epoch 5/20
# 718/718 [==============================] - ETA: 0s - loss: 1.7441 - accuracy: 0.2858
# Epoch 5: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 38ms/step - loss: 1.7441 - accuracy: 0.2858 - val_loss: 1.6618 - val_accuracy: 0.3389 - lr: 1.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.048373613040894e-05.
# Epoch 6/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.7222 - accuracy: 0.3002
# Epoch 6: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 29s 40ms/step - loss: 1.7223 - accuracy: 0.3002 - val_loss: 1.6894 - val_accuracy: 0.3204 - lr: 9.0484e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 8.187306229956448e-05.
# Epoch 7/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.7018 - accuracy: 0.3147
# Epoch 7: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 38ms/step - loss: 1.7016 - accuracy: 0.3148 - val_loss: 1.7787 - val_accuracy: 0.3285 - lr: 8.1873e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 7.408180681522936e-05.
# Epoch 8/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.6796 - accuracy: 0.3306
# Epoch 8: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 40ms/step - loss: 1.6795 - accuracy: 0.3305 - val_loss: 1.7113 - val_accuracy: 0.3018 - lr: 7.4082e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 6.703198596369475e-05.
# Epoch 9/20
# 718/718 [==============================] - ETA: 0s - loss: 1.6530 - accuracy: 0.3445
# Epoch 9: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.6530 - accuracy: 0.3445 - val_loss: 1.6827 - val_accuracy: 0.3448 - lr: 6.7032e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 6.065304478397593e-05.
# Epoch 10/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.6278 - accuracy: 0.3552
# Epoch 10: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.6280 - accuracy: 0.3551 - val_loss: 1.5194 - val_accuracy: 0.4046 - lr: 6.0653e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 5.488114038598724e-05.
# Epoch 11/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5966 - accuracy: 0.3737
# Epoch 11: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.5965 - accuracy: 0.3738 - val_loss: 1.7151 - val_accuracy: 0.3797 - lr: 5.4881e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.9658505304250866e-05.
# Epoch 12/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5727 - accuracy: 0.3840
# Epoch 12: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.5728 - accuracy: 0.3839 - val_loss: 1.6760 - val_accuracy: 0.3819 - lr: 4.9659e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.493287269724533e-05.
# Epoch 13/20
# 718/718 [==============================] - ETA: 0s - loss: 1.5588 - accuracy: 0.3903
# Epoch 13: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 38ms/step - loss: 1.5588 - accuracy: 0.3903 - val_loss: 1.4823 - val_accuracy: 0.4324 - lr: 4.4933e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.065694156452082e-05.
# Epoch 14/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5340 - accuracy: 0.4033
# Epoch 14: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 38ms/step - loss: 1.5341 - accuracy: 0.4031 - val_loss: 1.3840 - val_accuracy: 0.4687 - lr: 4.0657e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 3.678791836136952e-05.
# Epoch 15/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5209 - accuracy: 0.4100
# Epoch 15: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.5210 - accuracy: 0.4100 - val_loss: 1.3931 - val_accuracy: 0.4619 - lr: 3.6788e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 3.328708407934755e-05.
# Epoch 16/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.5095 - accuracy: 0.4143
# Epoch 16: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 29s 40ms/step - loss: 1.5098 - accuracy: 0.4142 - val_loss: 1.5409 - val_accuracy: 0.4321 - lr: 3.3287e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 3.0119397706585005e-05.
# Epoch 17/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.4969 - accuracy: 0.4187
# Epoch 17: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 29s 40ms/step - loss: 1.4972 - accuracy: 0.4186 - val_loss: 1.3602 - val_accuracy: 0.4700 - lr: 3.0119e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 2.7253156076767482e-05.
# Epoch 18/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.4775 - accuracy: 0.4300
# Epoch 18: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.4774 - accuracy: 0.4301 - val_loss: 1.3696 - val_accuracy: 0.4732 - lr: 2.7253e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 2.4659673727001064e-05.
# Epoch 19/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.4673 - accuracy: 0.4388
# Epoch 19: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 29s 40ms/step - loss: 1.4670 - accuracy: 0.4390 - val_loss: 1.3803 - val_accuracy: 0.4739 - lr: 2.4660e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 2.231299367849715e-05.
# Epoch 20/20
# 717/718 [============================>.] - ETA: 0s - loss: 1.4623 - accuracy: 0.4386
# Epoch 20: val_accuracy did not improve from 0.62940
# 718/718 [==============================] - 28s 39ms/step - loss: 1.4620 - accuracy: 0.4388 - val_loss: 1.3584 - val_accuracy: 0.4754 - lr: 2.2313e-05

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the best saved model
best_model = load_model('best_model.h5')

# Make predictions on the test set
predictions = best_model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_labels, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 225/225 [==============================] - 2s 7ms/step
